# %% [markdown]
# <a href="https://colab.research.google.com/github/vmaddi2-cloud/FDS-Titanic-Dataset/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Titanic-Dataset.csv")

print("First Five Records:")
print(df.head())
# Out:
# First Five Records:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("Dataset Information:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Summary Statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values

df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
df["Cabin"] = df["Cabin"].fillna("Unknown")

print("Missing Values After Filling:")
print(df.isnull().sum())
# Out:
# Missing Values After Filling:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Remove duplicate records

df = df.drop_duplicates()

print("Number of Records After Removing Duplicates:")
print(len(df))
# Out:
# Number of Records After Removing Duplicates:
# 891

# %%
# Encode categorical features

df["Sex"] = df["Sex"].map({"male": 0, "female": 1})

df["Embarked"] = df["Embarked"].map({"S": 0, "C": 1, "Q": 2})

print(df[["Sex", "Embarked"]].head())
# Out:
#    Sex  Embarked
# 0    0         0
# 1    1         1
# 2    1         0
# 3    1         0
# 4    0         0

# %%
# Normalize numeric features

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

cols = ["Age", "Fare"]

df[cols] = scaler.fit_transform(df[cols])

print(df[cols].head())
# Out:
#         Age      Fare
# 0  0.271174  0.014151
# 1  0.472229  0.139136
# 2  0.321438  0.015469
# 3  0.434531  0.103644
# 4  0.434531  0.015713

# %%
# Detect and remove outliers using IQR

Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df["Fare"] >= lower) & (df["Fare"] <= upper)]

print("Dataset After Removing Outliers:")
print(df.head())
# Out:
# Dataset After Removing Outliers:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name  Sex       Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    0  0.271174      1      0
# 2                        Heikkinen, Miss. Laina    1  0.321438      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  0.434531      1      0
# 4                      Allen, Mr. William Henry    0  0.434531      0      0
# 5                              Moran, Mr. James    0  0.367921      0      0
#
#              Ticket      Fare    Cabin  Embarked
# 0         A/5 21171  0.014151  Unknown         0
# 2  STON/O2. 3101282  0.015469  Unknown         0
# 3            113803  0.103644     C123         0
# 4            373450  0.015713  Unknown         0
# ...

# %%
# Compute correlation matrix

correlation_matrix = df.corr(numeric_only=True)

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.024438 -0.045179 -0.058468  0.015393 -0.080426
# Survived       -0.024438  1.000000 -0.238532  0.499888 -0.121283 -0.003156
# Pclass         -0.045179 -0.238532  1.000000 -0.011810 -0.342826  0.113943
# Sex            -0.058468  0.499888 -0.011810  1.000000 -0.130207  0.146035
# Age             0.015393 -0.121283 -0.342826 -0.130207  1.000000 -0.340947
# SibSp          -0.080426 -0.003156  0.113943  0.146035 -0.340947  1.000000
# Parch          -0.015117  0.098575  0.083451  0.289637 -0.212343  0.410182
# Fare            0.002942  0.234422 -0.589776  0.134106  0.078863  0.370388
# Embarked       -0.029666  0.083073  0.133963  0.112679 -0.016674 -0.042903
#
#                 Parch      Fare  Embarked
# PassengerId -0.015117  0.002942 -0.029666
# Survived     0.098575  0.234422  0.083073
# Pclass       0.083451 -0.589776  0.133963
# ...

# %%
# Visualize correlation matrix

plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Save the preprocessed dataset

df.to_csv("Titanic_Preprocessed.csv", index=False)

print("Preprocessed dataset saved successfully.")
# Out:
# Preprocessed dataset saved successfully.
